# %% [markdown]
# # Cell Image Example
#
# A example with image in the cell output and in the markdown.
#
#
# ![](../_static/bar_colors.png)
#
# ![gallery_thumbnail](../_static/barchart.png)
#
# Image example:
#
# ```{image} ../_static/bar_colors.png
#    :align: center
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x, y = np.meshgrid(np.linspace(-30, 30, 100), np.linspace(-30, 0, 50))

# values must be between 0 and 1
r = np.random.randint(0, 100, x.shape) / 100
g = np.random.randint(0, 100, x.shape) / 100
b = 0.4 * np.ones(x.shape)
a = np.random.randint(0, 100, x.shape) / 100

plt.figure(figsize=(10, 5))
plt.imshow(np.stack([r, g, b, a], axis=2), extent=[-30, 30, -30, 0])
plt.grid(True)
plt.show()
